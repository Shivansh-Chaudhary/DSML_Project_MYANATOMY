# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivansh-Chaudhary/DSML_Project_MYANATOMY/blob/main/Zomato_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/zomato_eda_mini_project.csv')

# %%
data.head()
# Out:
#   Restaurant Name     City              Cuisines  Average Cost for two  \
# 0     Ocean Pearl   Mumbai  Seafood, Continental                1450.0
# 1   Pizza Central     Pune        Pizza, Italian                 300.0
# 2      Cafe Aroma     Pune        Cafe, Desserts                 250.0
# 3      Cafe Aroma     Pune        Cafe, Desserts                1850.0
# 4  Bengal Kitchen  Kolkata                   NaN                 150.0
#
#    Price range  Aggregate rating  Votes
# 0            3               3.7  827.0
# 1            1               3.8  415.0
# 2            1               2.7  112.0
# 3            4               4.4  741.0
# 4            1               3.8  635.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant Name       103 non-null    object
#  1   City                  101 non-null    object
#  2   Cuisines              100 non-null    object
#  3   Average Cost for two  101 non-null    float64
#  4   Price range           103 non-null    int64
#  5   Aggregate rating      101 non-null    float64
#  6   Votes                 102 non-null    float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 5.8+ KB

# %%
# CountPlot "How many of each category"

# %%
#Which cuisins are most popular

# %%
sns.countplot(x="Cuisines" ,data= data)
# Out:
# <Axes: xlabel='Cuisines', ylabel='count'>

# %%
sns.histplot(x="Aggregate rating" ,y="Cuisines",data= data)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Cuisines'>

# %%
sns.histplot(x="Votes",data= data, kde=True)
# Out:
# <Axes: xlabel='Votes', ylabel='Count'>

# %%
sns.boxplot(x="City", y="Average Cost for two", data= data)
# Out:
# <Axes: xlabel='City', ylabel='Average Cost for two'>

# %%
sns.barplot(x="City", y="Average Cost for two", data= data)
# Out:
# <Axes: xlabel='City', ylabel='Average Cost for two'>

# %%
sns.barplot(x="City", y="Aggregate rating", data= data)
# Out:
# <Axes: xlabel='City', ylabel='Aggregate rating'>
